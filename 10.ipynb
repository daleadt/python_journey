# %%
import pandas as pd
Data={
"Year":["Mar26","Mar25","Mar24","Mar23","Mar22"],			 
"RFO":	[220938.00,	214853.00,	202359.00,	190354.00,	160341.00],	 
"TOR":	[220938.00,	214853.00,	202359.00,	190354.00,	160341.00], 
"OI":[10036.00,	9642.00, 7273.00,	5328.00,	7486.00],
"TR":[230974.00,	224495.00,	209632.00,	195682.00,	167827.00]}
df=pd.DataFrame(Data)
print(df)
# Out:
#     Year       RFO       TOR       OI        TR
# 0  Mar26  220938.0  220938.0  10036.0  230974.0
# 1  Mar25  214853.0  214853.0   9642.0  224495.0
# 2  Mar24  202359.0  202359.0   7273.0  209632.0
# 3  Mar23  190354.0  190354.0   5328.0  195682.0
# 4  Mar22  160341.0  160341.0   7486.0  167827.0

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Year"],df["TR"])
plt.ylabel("Year")
plt.xlabel("Total Revenue")
plt.title("Compare Year and Revenue")
plt.show()
